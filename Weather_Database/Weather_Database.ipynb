# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 723

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | ardakan
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | danilov
# Processing Record 5 of Set 1 | gizo
# Processing Record 6 of Set 1 | mackenzie
# Processing Record 7 of Set 1 | santa rosa
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | vanimo
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | balikpapan
# Processing Record 13 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | florence
# Processing Record 16 of Set 1 | skelleftea
# Processing Record 17 of Set 1 | rocha
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | kangaatsiaq
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | manokwari
# Processing Record 26 of Set 1 | khowst
# Processing Record 27 of Set 1 | cherskiy
# Processing Record 28 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | mount isa
# Processing Record 34 of Set 1 | mehamn
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | kavaratti
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | kjollefjord
# Processing Record 39 of Set 1 | skibbereen
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | cairns
# Processing Record 42 of Set 1 | necochea
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | leningradskiy
# Processing Record 45 of Set 1 | maniitsoq
# Processing Record 46 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | krasnoselkup
# Processing Record 48 of Set 1 | ust-kuyga
# Processing Record 49 of Set 1 | dunedin
# Processing Record 50 of Set 1 | leh
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | arraial do cabo
# Processing Record 4 of Set 2 | lompoc
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | grand gaube
# Processing Record 7 of Set 2 | srivardhan
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | tura
# Processing Record 10 of Set 2 | xining
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | mpika
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | narvik
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | daru
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | porto da folha
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | killybegs
# Processing Record 24 of Set 2 | sivaki
# Processing Record 25 of Set 2 | pumiao
# Processing Record 26 of Set 2 | bulungu
# Processing Record 27 of Set 2 | kashi
# Processing Record 28 of Set 2 | esperance
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | yerbogachen
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | hastings
# Processing Record 37 of Set 2 | shenzhen
# Processing Record 38 of Set 2 | koryukivka
# Processing Record 39 of Set 2 | two rivers
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | cayenne
# Processing Record 42 of Set 2 | pacific grove
# Processing Record 43 of Set 2 | avera
# Processing Record 44 of Set 2 | alofi
# Processing Record 45 of Set 2 | palana
# Processing Record 46 of Set 2 | zyryanovsk
# Processing Record 47 of Set 2 | severo-kurilsk
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | leiyang
# Processing Record 50 of Set 2 | ratnagiri
# Processing Record 1 of Set 3 | kilindoni
# Processing Record 2 of Set 3 | noumea
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | sioux lookout
# Processing Record 5 of Set 3 | qasigiannguit
# Processing Record 6 of Set 3 | togur
# Processing Record 7 of Set 3 | wuchi
# Processing Record 8 of Set 3 | san quintin
# Processing Record 9 of Set 3 | ushirombo
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | abbeville
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | rab
# City not found. Skipping...
# Processing Record 15 of Set 3 | vanavara
# Processing Record 16 of Set 3 | xuddur
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | zhigansk
# Processing Record 20 of Set 3 | bud
# Processing Record 21 of Set 3 | mataura
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | pacifica
# Processing Record 24 of Set 3 | tessalit
# Processing Record 25 of Set 3 | brae
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | parrita
# Processing Record 28 of Set 3 | bonthe
# Processing Record 29 of Set 3 | perth
# Processing Record 30 of Set 3 | salym
# Processing Record 31 of Set 3 | roald
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | quatre cocos
# Processing Record 34 of Set 3 | iqaluit
# Processing Record 35 of Set 3 | sinnamary
# Processing Record 36 of Set 3 | chicama
# Processing Record 37 of Set 3 | cambridge
# Processing Record 38 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | negara
# Processing Record 41 of Set 3 | haines junction
# Processing Record 42 of Set 3 | hambantota
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | andenes
# Processing Record 46 of Set 3 | buin
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | kandrian
# Processing Record 49 of Set 3 | kirakira
# Processing Record 50 of Set 3 | ketchikan
# Processing Record 1 of Set 4 | orsha
# Processing Record 2 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | shiloh
# Processing Record 6 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 4 | yendi
# Processing Record 8 of Set 4 | middelburg
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | inongo
# Processing Record 11 of Set 4 | constitucion
# Processing Record 12 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 13 of Set 4 | chuy
# Processing Record 14 of Set 4 | neiafu
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | port macquarie
# Processing Record 17 of Set 4 | katsuura
# Processing Record 18 of Set 4 | sikasso
# Processing Record 19 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 4 | camabatela
# Processing Record 21 of Set 4 | biak
# Processing Record 22 of Set 4 | vangaindrano
# Processing Record 23 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 4 | kogon
# Processing Record 25 of Set 4 | saldanha
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | umea
# Processing Record 28 of Set 4 | khani
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | stepnyak
# Processing Record 31 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 32 of Set 4 | karratha
# Processing Record 33 of Set 4 | howard springs
# Processing Record 34 of Set 4 | lata
# Processing Record 35 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 4 | ayagoz
# Processing Record 37 of Set 4 | sakakah
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | tukrah
# Processing Record 40 of Set 4 | luderitz
# Processing Record 41 of Set 4 | bandarbeyla
# Processing Record 42 of Set 4 | santa maria
# Processing Record 43 of Set 4 | payo
# Processing Record 44 of Set 4 | namatanai
# Processing Record 45 of Set 4 | sabalgarh
# Processing Record 46 of Set 4 | bubaque
# Processing Record 47 of Set 4 | kosh-agach
# Processing Record 48 of Set 4 | margate
# Processing Record 49 of Set 4 | paoua
# Processing Record 50 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 5 | ponta do sol
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | provideniya
# Processing Record 4 of Set 5 | glendive
# Processing Record 5 of Set 5 | kruisfontein
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | salaberry-de-valleyfield
# Processing Record 8 of Set 5 | srednekolymsk
# Processing Record 9 of Set 5 | port lincoln
# Processing Record 10 of Set 5 | acayuca
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 5 | port elizabeth
# Processing Record 14 of Set 5 | kazerun
# Processing Record 15 of Set 5 | benguela
# Processing Record 16 of Set 5 | ambon
# Processing Record 17 of Set 5 | jaciara
# Processing Record 18 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 5 | camana
# Processing Record 20 of Set 5 | ocosingo
# Processing Record 21 of Set 5 | hailar
# Processing Record 22 of Set 5 | shahabad
# Processing Record 23 of Set 5 | dalaba
# Processing Record 24 of Set 5 | muli
# Processing Record 25 of Set 5 | lake charles
# Processing Record 26 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 5 | yilan
# Processing Record 28 of Set 5 | mecca
# Processing Record 29 of Set 5 | carutapera
# Processing Record 30 of Set 5 | ahipara
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | miranda
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | saint george
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | taldan
# Processing Record 39 of Set 5 | disa
# Processing Record 40 of Set 5 | jasa tomic
# Processing Record 41 of Set 5 | svetlyy
# Processing Record 42 of Set 5 | wallasey
# Processing Record 43 of Set 5 | yuzhno-kurilsk
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | robertsport
# Processing Record 46 of Set 5 | te anau
# Processing Record 47 of Set 5 | namibe
# Processing Record 48 of Set 5 | bouafle
# Processing Record 49 of Set 5 | richards bay
# Processing Record 50 of Set 5 | coari
# Processing Record 1 of Set 6 | inhambane
# Processing Record 2 of Set 6 | nieuw amsterdam
# Processing Record 3 of Set 6 | mayo
# Processing Record 4 of Set 6 | kabo
# Processing Record 5 of Set 6 | bogotol
# Processing Record 6 of Set 6 | dicabisagan
# Processing Record 7 of Set 6 | pevek
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | agadez
# Processing Record 10 of Set 6 | aksarka
# Processing Record 11 of Set 6 | stromness
# Processing Record 12 of Set 6 | ambilobe
# Processing Record 13 of Set 6 | gigmoto
# Processing Record 14 of Set 6 | hay river
# Processing Record 15 of Set 6 | asau
# Processing Record 16 of Set 6 | teya
# Processing Record 17 of Set 6 | lagoa
# Processing Record 18 of Set 6 | coihaique
# Processing Record 19 of Set 6 | sur
# Processing Record 20 of Set 6 | the valley
# Processing Record 21 of Set 6 | waingapu
# Processing Record 22 of Set 6 | ribeira grande
# Processing Record 23 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 24 of Set 6 | dharchula
# Processing Record 25 of Set 6 | praya
# Processing Record 26 of Set 6 | beloha
# Processing Record 27 of Set 6 | codrington
# Processing Record 28 of Set 6 | dikson
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | mitchell
# Processing Record 31 of Set 6 | porto novo
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | betong
# Processing Record 34 of Set 6 | santa lucia
# Processing Record 35 of Set 6 | bay roberts
# Processing Record 36 of Set 6 | castro
# Processing Record 37 of Set 6 | khandela
# Processing Record 38 of Set 6 | usogorsk
# Processing Record 39 of Set 6 | fuxin
# Processing Record 40 of Set 6 | manjakandriana
# Processing Record 41 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 6 | mocuba
# Processing Record 43 of Set 6 | erzin
# Processing Record 44 of Set 6 | dawson creek
# Processing Record 45 of Set 6 | vardo
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 48 of Set 6 | pitkyaranta
# Processing Record 49 of Set 6 | honningsvag
# Processing Record 50 of Set 6 | comodoro rivadavia
# Processing Record 1 of Set 7 | marigot
# Processing Record 2 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | camposampiero
# Processing Record 5 of Set 7 | suhbaatar
# Processing Record 6 of Set 7 | pak phanang
# Processing Record 7 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 7 | pafos
# Processing Record 9 of Set 7 | dhidhdhoo
# Processing Record 10 of Set 7 | puerto leguizamo
# Processing Record 11 of Set 7 | mega
# Processing Record 12 of Set 7 | brovary
# Processing Record 13 of Set 7 | olafsvik
# Processing Record 14 of Set 7 | saskylakh
# Processing Record 15 of Set 7 | ajdabiya
# Processing Record 16 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 7 | hobyo
# Processing Record 19 of Set 7 | dekar
# Processing Record 20 of Set 7 | whitehorse
# Processing Record 21 of Set 7 | venado tuerto
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | sanming
# Processing Record 24 of Set 7 | anadyr
# Processing Record 25 of Set 7 | katima mulilo
# Processing Record 26 of Set 7 | kalabo
# Processing Record 27 of Set 7 | camalu
# Processing Record 28 of Set 7 | aviles
# Processing Record 29 of Set 7 | hasaki
# Processing Record 30 of Set 7 | zhucheng
# Processing Record 31 of Set 7 | chulym
# Processing Record 32 of Set 7 | northview
# Processing Record 33 of Set 7 | solnechnyy
# Processing Record 34 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 7 | sarandi
# Processing Record 36 of Set 7 | muroto
# Processing Record 37 of Set 7 | kyra
# Processing Record 38 of Set 7 | college
# Processing Record 39 of Set 7 | zaranj
# Processing Record 40 of Set 7 | rio grande
# Processing Record 41 of Set 7 | bollnas
# Processing Record 42 of Set 7 | veraval
# Processing Record 43 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 7 | colgong
# Processing Record 45 of Set 7 | nishihara
# Processing Record 46 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 7 | bitung
# Processing Record 48 of Set 7 | oussouye
# Processing Record 49 of Set 7 | batagay-alyta
# Processing Record 50 of Set 7 | velke hamry
# Processing Record 1 of Set 8 | jiayuguan
# Processing Record 2 of Set 8 | maunabo
# Processing Record 3 of Set 8 | schela
# Processing Record 4 of Set 8 | bathsheba
# Processing Record 5 of Set 8 | ahome
# Processing Record 6 of Set 8 | panjwin
# City not found. Skipping...
# Processing Record 7 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 8 | la asuncion
# Processing Record 9 of Set 8 | broken hill
# Processing Record 10 of Set 8 | grindavik
# Processing Record 11 of Set 8 | ancud
# Processing Record 12 of Set 8 | sarangani
# Processing Record 13 of Set 8 | tsagan aman
# Processing Record 14 of Set 8 | hofn
# Processing Record 15 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 16 of Set 8 | bengkulu
# Processing Record 17 of Set 8 | finnsnes
# Processing Record 18 of Set 8 | mahon
# Processing Record 19 of Set 8 | ullapool
# Processing Record 20 of Set 8 | fairbanks
# Processing Record 21 of Set 8 | channel-port aux basques
# Processing Record 22 of Set 8 | samarai
# Processing Record 23 of Set 8 | paamiut
# Processing Record 24 of Set 8 | belyy yar
# Processing Record 25 of Set 8 | lavrentiya
# Processing Record 26 of Set 8 | tripoli
# Processing Record 27 of Set 8 | mitu
# Processing Record 28 of Set 8 | souillac
# Processing Record 29 of Set 8 | nortelandia
# Processing Record 30 of Set 8 | grand-santi
# Processing Record 31 of Set 8 | fayaoue
# Processing Record 32 of Set 8 | ulverstone
# Processing Record 33 of Set 8 | vilhena
# Processing Record 34 of Set 8 | mount gambier
# Processing Record 35 of Set 8 | phumi samraong
# City not found. Skipping...
# Processing Record 36 of Set 8 | port hedland
# Processing Record 37 of Set 8 | norman wells
# Processing Record 38 of Set 8 | port keats
# Processing Record 39 of Set 8 | senigallia
# Processing Record 40 of Set 8 | phonhong
# Processing Record 41 of Set 8 | price
# Processing Record 42 of Set 8 | retz
# Processing Record 43 of Set 8 | samfya
# Processing Record 44 of Set 8 | lasa
# Processing Record 45 of Set 8 | stornoway
# Processing Record 46 of Set 8 | akyab
# Processing Record 47 of Set 8 | bossangoa
# Processing Record 48 of Set 8 | darhan
# Processing Record 49 of Set 8 | calvinia
# Processing Record 50 of Set 8 | ambulu
# Processing Record 1 of Set 9 | shimoda
# Processing Record 2 of Set 9 | juneau
# Processing Record 3 of Set 9 | marsaxlokk
# Processing Record 4 of Set 9 | derzhavinsk
# Processing Record 5 of Set 9 | san cristobal
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | ankang
# Processing Record 8 of Set 9 | pitimbu
# Processing Record 9 of Set 9 | kushima
# Processing Record 10 of Set 9 | pinerolo
# Processing Record 11 of Set 9 | dennery
# Processing Record 12 of Set 9 | suntar
# Processing Record 13 of Set 9 | adre
# Processing Record 14 of Set 9 | praia
# Processing Record 15 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 9 | kitgum
# Processing Record 17 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 9 | paracuru
# Processing Record 19 of Set 9 | saint anthony
# Processing Record 20 of Set 9 | tungor
# Processing Record 21 of Set 9 | novoagansk
# Processing Record 22 of Set 9 | nome
# Processing Record 23 of Set 9 | lianran
# Processing Record 24 of Set 9 | cuautepec
# Processing Record 25 of Set 9 | mahebourg
# Processing Record 26 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 9 | kathmandu
# Processing Record 28 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | scranton
# Processing Record 31 of Set 9 | dustlik
# Processing Record 32 of Set 9 | oksbol
# Processing Record 33 of Set 9 | saryg-sep
# Processing Record 34 of Set 9 | mandera
# Processing Record 35 of Set 9 | gat
# Processing Record 36 of Set 9 | madaoua
# Processing Record 37 of Set 9 | toamasina
# Processing Record 38 of Set 9 | hurghada
# Processing Record 39 of Set 9 | turangi
# Processing Record 40 of Set 9 | ostrovnoy
# Processing Record 41 of Set 9 | chapais
# Processing Record 42 of Set 9 | zaqatala
# Processing Record 43 of Set 9 | oudtshoorn
# Processing Record 44 of Set 9 | huilong
# Processing Record 45 of Set 9 | kuytun
# Processing Record 46 of Set 9 | port said
# Processing Record 47 of Set 9 | imphal
# Processing Record 48 of Set 9 | isa khel
# Processing Record 49 of Set 9 | caravelas
# Processing Record 50 of Set 9 | oranjestad
# Processing Record 1 of Set 10 | taltal
# Processing Record 2 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 3 of Set 10 | saint-paul
# Processing Record 4 of Set 10 | houston
# Processing Record 5 of Set 10 | muros
# Processing Record 6 of Set 10 | ustye
# Processing Record 7 of Set 10 | maragogi
# Processing Record 8 of Set 10 | gari
# Processing Record 9 of Set 10 | weligama
# Processing Record 10 of Set 10 | touros
# Processing Record 11 of Set 10 | salisbury
# Processing Record 12 of Set 10 | waterloo
# Processing Record 13 of Set 10 | tezu
# Processing Record 14 of Set 10 | gariaband
# Processing Record 15 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 10 | ponta delgada
# Processing Record 17 of Set 10 | chegdomyn
# Processing Record 18 of Set 10 | andros town
# Processing Record 19 of Set 10 | lethem
# Processing Record 20 of Set 10 | kuah
# Processing Record 21 of Set 10 | springdale
# Processing Record 22 of Set 10 | tashara
# Processing Record 23 of Set 10 | grenaa
# Processing Record 24 of Set 10 | bodmin
# Processing Record 25 of Set 10 | amuntai
# Processing Record 26 of Set 10 | aykhal
# Processing Record 27 of Set 10 | laguna
# Processing Record 28 of Set 10 | chunskiy
# Processing Record 29 of Set 10 | husavik
# Processing Record 30 of Set 10 | puerto escondido
# Processing Record 31 of Set 10 | aklavik
# Processing Record 32 of Set 10 | yumen
# Processing Record 33 of Set 10 | mackay
# Processing Record 34 of Set 10 | fortuna
# Processing Record 35 of Set 10 | nynashamn
# Processing Record 36 of Set 10 | anchorage
# Processing Record 37 of Set 10 | rio cuarto
# Processing Record 38 of Set 10 | gavrilov posad
# Processing Record 39 of Set 10 | mombetsu
# Processing Record 40 of Set 10 | acarau
# Processing Record 41 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 42 of Set 10 | mpwapwa
# Processing Record 43 of Set 10 | belmonte
# Processing Record 44 of Set 10 | saint-pacome
# City not found. Skipping...
# Processing Record 45 of Set 10 | coolum beach
# Processing Record 46 of Set 10 | tocopilla
# Processing Record 47 of Set 10 | burns lake
# Processing Record 48 of Set 10 | kavieng
# Processing Record 49 of Set 10 | zeya
# Processing Record 50 of Set 10 | nouakchott
# Processing Record 1 of Set 11 | los llanos de aridane
# Processing Record 2 of Set 11 | lichuan
# Processing Record 3 of Set 11 | zenzeli
# Processing Record 4 of Set 11 | jacksonville
# Processing Record 5 of Set 11 | faya
# Processing Record 6 of Set 11 | sao jose da coroa grande
# Processing Record 7 of Set 11 | kieta
# Processing Record 8 of Set 11 | manzhouli
# Processing Record 9 of Set 11 | besleney
# Processing Record 10 of Set 11 | sao felix do xingu
# Processing Record 11 of Set 11 | sao filipe
# Processing Record 12 of Set 11 | corinto
# Processing Record 13 of Set 11 | bozoum
# Processing Record 14 of Set 11 | sijunjung
# Processing Record 15 of Set 11 | grande prairie
# Processing Record 16 of Set 11 | baneh
# Processing Record 17 of Set 11 | concepcion
# Processing Record 18 of Set 11 | kondinskoye
# Processing Record 19 of Set 11 | gushikawa
# Processing Record 20 of Set 11 | tautira
# Processing Record 21 of Set 11 | polyanka
# Processing Record 22 of Set 11 | kurilsk
# Processing Record 23 of Set 11 | klyuchevskiy
# Processing Record 24 of Set 11 | monrovia
# Processing Record 25 of Set 11 | bambanglipuro
# Processing Record 26 of Set 11 | kasempa
# Processing Record 27 of Set 11 | kamaishi
# Processing Record 28 of Set 11 | ferrol
# Processing Record 29 of Set 11 | wanaka
# Processing Record 30 of Set 11 | pangnirtung
# Processing Record 31 of Set 11 | russell
# Processing Record 32 of Set 11 | axim
# Processing Record 33 of Set 11 | clyde river
# Processing Record 34 of Set 11 | tagusao
# Processing Record 35 of Set 11 | nola
# Processing Record 36 of Set 11 | vavatenina
# Processing Record 37 of Set 11 | riyadh
# Processing Record 38 of Set 11 | berlevag
# Processing Record 39 of Set 11 | scarborough
# Processing Record 40 of Set 11 | kismayo
# Processing Record 41 of Set 11 | kahului
# Processing Record 42 of Set 11 | rincon
# Processing Record 43 of Set 11 | flinders
# Processing Record 44 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 11 | sao joao da barra
# Processing Record 46 of Set 11 | ljungby
# Processing Record 47 of Set 11 | omboue
# Processing Record 48 of Set 11 | papara
# Processing Record 49 of Set 11 | exeter
# Processing Record 50 of Set 11 | callaway
# Processing Record 1 of Set 12 | oskemen
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | mananjary
# Processing Record 4 of Set 12 | juba
# Processing Record 5 of Set 12 | kansanshi
# Processing Record 6 of Set 12 | iranshahr
# Processing Record 7 of Set 12 | liniere
# City not found. Skipping...
# Processing Record 8 of Set 12 | nanortalik
# Processing Record 9 of Set 12 | tarabuco
# Processing Record 10 of Set 12 | chifeng
# Processing Record 11 of Set 12 | vila
# Processing Record 12 of Set 12 | sorland
# Processing Record 13 of Set 12 | oranjemund
# Processing Record 14 of Set 12 | galle
# Processing Record 15 of Set 12 | blind river
# Processing Record 16 of Set 12 | prince rupert
# Processing Record 17 of Set 12 | neuquen
# Processing Record 18 of Set 12 | vila velha
# Processing Record 19 of Set 12 | bekhtery
# Processing Record 20 of Set 12 | vieques
# Processing Record 21 of Set 12 | pushkino
# Processing Record 22 of Set 12 | yurimaguas
# Processing Record 23 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 12 | serenje
# Processing Record 25 of Set 12 | manaus
# Processing Record 26 of Set 12 | biskamzha
# Processing Record 27 of Set 12 | usak
# Processing Record 28 of Set 12 | wysokie mazowieckie
# Processing Record 29 of Set 12 | le havre
# Processing Record 30 of Set 12 | sorokino
# Processing Record 31 of Set 12 | marataizes
# Processing Record 32 of Set 12 | maun
# Processing Record 33 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 12 | colimes
# Processing Record 35 of Set 12 | mbandaka
# Processing Record 36 of Set 12 | bayangol
# Processing Record 37 of Set 12 | saint-pierre
# Processing Record 38 of Set 12 | cockburn town
# Processing Record 39 of Set 12 | port hardy
# Processing Record 40 of Set 12 | las palmas
# Processing Record 41 of Set 12 | la ronge
# Processing Record 42 of Set 12 | tangier
# Processing Record 43 of Set 12 | salalah
# Processing Record 44 of Set 12 | soubre
# Processing Record 45 of Set 12 | acajutla
# Processing Record 46 of Set 12 | tilichiki
# Processing Record 47 of Set 12 | mamallapuram
# Processing Record 48 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 12 | byron bay
# Processing Record 50 of Set 12 | eha amufu
# Processing Record 1 of Set 13 | bulgan
# Processing Record 2 of Set 13 | tiarei
# Processing Record 3 of Set 13 | tecoanapa
# Processing Record 4 of Set 13 | stonewall
# Processing Record 5 of Set 13 | kamiiso
# Processing Record 6 of Set 13 | morant bay
# Processing Record 7 of Set 13 | sola
# Processing Record 8 of Set 13 | kapuskasing
# Processing Record 9 of Set 13 | catamarca
# Processing Record 10 of Set 13 | lyantonde
# Processing Record 11 of Set 13 | mujiayingzi
# Processing Record 12 of Set 13 | emerald
# Processing Record 13 of Set 13 | dali
# Processing Record 14 of Set 13 | pangai
# Processing Record 15 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 13 | najran
# Processing Record 17 of Set 13 | krasnovishersk
# Processing Record 18 of Set 13 | amga
# Processing Record 19 of Set 13 | varhaug
# Processing Record 20 of Set 13 | san vicente
# Processing Record 21 of Set 13 | new britain
# Processing Record 22 of Set 13 | tsabong
# Processing Record 23 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 13 | westport
# Processing Record 25 of Set 13 | katha
# City not found. Skipping...
# Processing Record 26 of Set 13 | bafia
# Processing Record 27 of Set 13 | omagh
# Processing Record 28 of Set 13 | dingle
# Processing Record 29 of Set 13 | wyndham
# Processing Record 30 of Set 13 | meulaboh
# Processing Record 31 of Set 13 | dumai
# Processing Record 32 of Set 13 | timmins
# Processing Record 33 of Set 13 | umm kaddadah
# Processing Record 34 of Set 13 | consett
# Processing Record 35 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 13 | znamenskoye
# Processing Record 37 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 13 | capoterra
# Processing Record 39 of Set 13 | barra patuca
# Processing Record 40 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 13 | atar
# Processing Record 42 of Set 13 | male
# Processing Record 43 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 45 of Set 13 | zaltan
# Processing Record 46 of Set 13 | batemans bay
# Processing Record 47 of Set 13 | olinda
# Processing Record 48 of Set 13 | omsukchan
# Processing Record 49 of Set 13 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 50 of Set 13 | theog
# Processing Record 1 of Set 14 | bahua
# Processing Record 2 of Set 14 | vestmannaeyjar
# Processing Record 3 of Set 14 | staryy nadym
# Processing Record 4 of Set 14 | yatou
# Processing Record 5 of Set 14 | vostok
# Processing Record 6 of Set 14 | shahr-e babak
# Processing Record 7 of Set 14 | uige
# Processing Record 8 of Set 14 | zhangye
# Processing Record 9 of Set 14 | manono
# Processing Record 10 of Set 14 | sistranda
# Processing Record 11 of Set 14 | zhangjiakou
# Processing Record 12 of Set 14 | sligo
# Processing Record 13 of Set 14 | bousso
# Processing Record 14 of Set 14 | san francisco del mar
# Processing Record 15 of Set 14 | opuwo
# Processing Record 16 of Set 14 | chantada
# Processing Record 17 of Set 14 | saluzzo
# Processing Record 18 of Set 14 | tondano
# Processing Record 19 of Set 14 | santa rosalia
# Processing Record 20 of Set 14 | jega
# Processing Record 21 of Set 14 | marquard
# Processing Record 22 of Set 14 | meadow lake
# Processing Record 23 of Set 14 | tahta
# Processing Record 24 of Set 14 | tuatapere
# Processing Record 25 of Set 14 | jackson
# Processing Record 26 of Set 14 | dosso
# Processing Record 27 of Set 14 | namie
# Processing Record 28 of Set 14 | prieska
# Processing Record 29 of Set 14 | verkhnevilyuysk
# Processing Record 30 of Set 14 | pokhara
# Processing Record 31 of Set 14 | goure
# Processing Record 32 of Set 14 | freital
# Processing Record 33 of Set 14 | tougue
# Processing Record 34 of Set 14 | merauke
# Processing Record 35 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 14 | skjervoy
# Processing Record 37 of Set 14 | terre haute
# Processing Record 38 of Set 14 | labuhan
# Processing Record 39 of Set 14 | ilhabela
# Processing Record 40 of Set 14 | batagay
# Processing Record 41 of Set 14 | kletskaya
# Processing Record 42 of Set 14 | carbonia
# Processing Record 43 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 44 of Set 14 | roma
# Processing Record 45 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 14 | osa
# Processing Record 47 of Set 14 | bundaberg
# Processing Record 48 of Set 14 | navoi
# Processing Record 49 of Set 14 | majene
# Processing Record 50 of Set 14 | fort wellington
# Processing Record 1 of Set 15 | terrace
# Processing Record 2 of Set 15 | niteroi
# Processing Record 3 of Set 15 | cortez
# Processing Record 4 of Set 15 | bonavista
# Processing Record 5 of Set 15 | bageshwar
# Processing Record 6 of Set 15 | winslow
# Processing Record 7 of Set 15 | pau brasil
# Processing Record 8 of Set 15 | wajir
# Processing Record 9 of Set 15 | kaeo
# Processing Record 10 of Set 15 | bandar
# Processing Record 11 of Set 15 | piotrkow trybunalski
# Processing Record 12 of Set 15 | urut
# Processing Record 13 of Set 15 | kaili
# Processing Record 14 of Set 15 | sogdiondon
# City not found. Skipping...
# Processing Record 15 of Set 15 | jacareacanga
# Processing Record 16 of Set 15 | boddam
# Processing Record 17 of Set 15 | lamar
# Processing Record 18 of Set 15 | sokolo
# Processing Record 19 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 15 | rundu
# Processing Record 21 of Set 15 | tambovka
# Processing Record 22 of Set 15 | goderich
# Processing Record 23 of Set 15 | isangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     55.04        67          65
# 1       Ardakan      IR  32.3100   54.0175     82.78        15           0
# 2         Vaini      TO -21.2000 -175.2000     69.96        83          75
# 3       Danilov      RU  58.1908   40.1717     53.94        96           0
# 4          Gizo      SB  -8.1030  156.8419     83.62        71          93
# 5     Mackenzie      CA  55.2999 -123.1698     68.22        34          75
# 6    Santa Rosa      PH  14.3122  121.1114     81.91        88         100
# 7  Punta Arenas      CL -53.1500  -70.9167     44.71        81          75
# 8        Vanimo      PG  -2.6741  141.3028     86.25        67          20
# 9        Albany      US  42.6001  -73.9662     67.95        92         100
#
#    Wind Speed Current Description
# 0       16.64       broken clouds
# 1        8.63           clear sky
# 2        8.05       broken clouds
# 3        2.26           clear sky
# 4        7.27          light rain
# 5        5.75       broken clouds
# 6       17.56          light rain
# 7       23.02       broken clouds
# 8        5.91          few clouds
# 9        2.04     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
